# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvshan05/matplot_lib_everything/blob/main/02barchart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
plt.bar(company,revenue)
#ye to simply ho gya yaar
# Out:
# <BarContainer object of 4 artists>

# %%
xpos=np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(xpos,company)
plt.bar(xpos,revenue ,label='revenue')
plt.ylabel('revneue in billion')
plt.title('us stocks')
plt.legend()

# %%
profit=[40,2,34,12]

# %%
plt.bar(xpos-0.2,revenue,width=0.4,label='revenue')
plt.bar(xpos+0.2,profit,width=0.4,label='profit')
plt.xticks(xpos,company)
plt.ylabel('revenue')
plt.title('us stoks')
plt.legend()

# %%
#for horizontal bar replace bar wid barh
plt.barh(xpos,revenue,label='revenue')
plt.barh(xpos,profit,label='profit')
plt.yticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technolog Stocks')
plt.legend()
